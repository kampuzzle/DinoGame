# %%
import seaborn as sns
import matplotlib.pyplot as plt

def boxplot():
    result1 = [24.5, 24.25, 85.75, 24.5, 24.0, 24.5, 86.5, 24.25, 80.25, 24.5, 24.5, 83.0, 24.0, 24.0, 24.25, 148.5, 53.25, 24.5, 94.25, 24.5, 24.5, 77.5, 24.5, 36.75]
    result2 = [24.5, 32.8, 24.5, 69.75, 86.25, 24.5, 52.5, 77.5, 24.5, 36.75, 24.5, 42.5, 24.25, 32.5, 23.25, 29.5, 24.0, 24.5, 24.5, 33.75, 24.5, 24.5, 24.25, 24.5]
    result3 = [24.0, 47.75, 24.5, 24.75, 24.5, 24.5, 24.5, 24.0, 45.0, 24.0, 58.5, 24.0, 98.0, 24.5, 52.75, 24.5, 24.5, 202.5, 28.5, 34.5, 24.0, 46.0, 24.0, 24.5]
    result4 = [33.5, 44.5, 24.5, 24.5, 24.0, 56.5, 24.5, 45.0, 73.25, 24.0, 24.5, 110.75, 24.0, 24.0, 98.25, 87.5, 24.0, 24.5, 24.0, 24.5, 24.75, 24.5, 24.5, 24.5]
    # adicionar label "pontuação" e "rodadas"
    plt.ylabel("Pontuação")
    sns.boxplot(data=[result1, result2, result3, result4])
    plt.show()
    
boxplot()

# %%
top_scores = [
    28.6244, 35.1387, 36.1654, 38.1875, 38.1875,
    38.80208, 38.95836, 40.84375, 40.84375,
    41.78125, 41.78125, 42.46875, 42.46875, 43.10416,
    45.32291, 45.32291, 48.76389, 48.76389, 53.53940,
    56.31250
]

x_values = range(1, len(top_scores) + 1)

plt.plot(x_values, top_scores, marker='o', linestyle='-', color='blue')
plt.xlabel('Rodada')
plt.ylabel('Top Score')
plt.title('Desempenho do Top Score ao Longo do Tempo')
plt.xticks(x_values)
plt.show()
